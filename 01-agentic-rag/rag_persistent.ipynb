# %%
from rag_helper import RAGHelper
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()
# Out:
# True

# %%
from sqlitesearch import TextSearchIndex

sqlite_index = TextSearchIndex(
  text_fields=['question', 'section', 'answer'],
  keyword_fields=['course'],
  db_path='faq.db'
)

# %%
openai_client = OpenAI()

assistant = RAGHelper(sqlite_index, openai_client)

# %%
assistant.rag('Tell me about the course')
# Out:
# 'Here’s a quick overview of the course based on the provided context:\n\n- It’s the **LLM Zoomcamp** course.\n- You can start by checking:\n  - the **LLM Zoomcamp docs**\n  - the **general Zoomcamp logistics docs**\n  - the **LLM Zoomcamp GitHub repository**\n\n### How to follow the course\nA typical weekly workflow is:\n\n1. Watch the lesson videos  \n2. Work through the lesson notebooks/code  \n3. Read the homework instructions on GitHub  \n4. Submit your answers through the course platform before the deadline  \n\nHomework follows the lesson flow, but usually uses a different dataset or a slightly different task.\n\n### Joining and registration\n- You can **start whenever you want**\n- Videos and GitHub materials are available\n- Deadlines are listed in the **course management platform**\n- You **don’t need a confirmation email** to participate\n- You’re considered accepted, and you can start learning and submitting homework while the form is open\n- Registration is mainly used to gauge interest\n\n### Certificate\n- If you discovered the course late, you can still join\n- But to receive a certificate, you need to submit your project while submissions are still being accepted\n\n### Communication\n- **Telegram channel:** https://t.me/llm_zoomcamp  \n  Use it for announcements\n- For technical questions and discussion, use the **course Slack channel**\n\n### Next offering\n- The course will be offered next in **Summer 2027**.'
